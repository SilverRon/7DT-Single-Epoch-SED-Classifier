# %% [markdown]
# # Setting

# %% [markdown]
# ## Library

# %%
import os, sys, json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import warnings
warnings.filterwarnings("ignore")

# %%
# Matplotlib global settings
mpl.rcParams["axes.titlesize"] = 14
mpl.rcParams["axes.labelsize"] = 20
plt.rcParams['savefig.dpi'] = 500
plt.rc('font', family='serif')

# %%
# ML libraries
from sklearn.model_selection import GroupShuffleSplit
from sklearn.preprocessing import LabelEncoder

# %%
# Helper functions & model import
sys.path.append(os.path.join('..', 'src'))
from helper import makeSpecColors
from paths import *
from var import *
from sdtpy import *
from model import *

# %% [markdown]
# ## Function

# %%
def select_uids_by_class(df, sample_number, class_col='Class', uid_col='uid', random_state=42):
    np.random.seed(random_state)
    uids_by_class = {}
    for c in df[class_col].unique():
        uids = df[df[class_col]==c][uid_col].unique()
        n_select = min(sample_number, len(uids))
        selected_uids = np.random.choice(uids, n_select, replace=False)
        uids_by_class[c] = set(selected_uids)
    return uids_by_class

# %%
def filter_by_selected_uids(df, uids_by_class, class_col='Class', uid_col='uid'):
    mask = np.zeros(len(df), dtype=bool)
    for c, uids in uids_by_class.items():
        mask |= ((df[class_col]==c) & (df[uid_col].isin(uids)))
    return df[mask]

# %%
from sklearn.model_selection import GroupShuffleSplit

def train_test_split_by_uid(df, test_size=0.2, class_col='Class', uid_col='uid', random_state=42):
    groups = df[uid_col]
    gss = GroupShuffleSplit(n_splits=1, test_size=test_size, random_state=random_state)
    train_idx, test_idx = next(gss.split(df, df[class_col], groups))
    return df.iloc[train_idx], df.iloc[test_idx]

# %% [markdown]
# ## Initial Setup

# %%
logtxt = ""

# %%
# Set experiment configs
random_state = 42
test_size = 0.2
device_type = "gpu" # or gpu
n_jobs = 5
#
test_name = "Rubin_7DT_XGBoost"
path_save = os.path.join(MODEL, test_name)
os.makedirs(path_save, exist_ok=True)
#

logtxt += "\nSet experiment configs\n"
# logtxt += f"test_name: {test_name}\n"
logtxt += f"random_state: {random_state}\n"
logtxt += f"test_size: {test_size}\n"
logtxt += f"device_type: {device_type}\n"
logtxt += f"n_jobs: {n_jobs}\n"
logtxt += f"path_save: {path_save}\n"
logtxt += "\n"

# %% [markdown]
# - Source to Consider

# %%
sources_to_consider = [
	"AGN", 
	"Ia", 
	"II", 
	"Ibc", 
	"LBV", 
	"TDE", 
	"Nova", 
	"M dwarf", 
	"CV",
	"SLSN",
]
logtxt += f"\nSources to consider: {sources_to_consider}\n"

# %%
path_data = os.path.join(FEATURE_BALANCED_DATA, 'features_rubin_7dt40.csv')

logtxt += f"\nBalanced Data Set\n"

# %% [markdown]
# # Data

# %%
# columns_to_use = list(data_dtype_dict.keys())

# %%
data = pd.read_csv(
    path_data,
    engine='c', 
    # usecols=columns_to_use,
    # dtype=data_dtype_dict,
)

data['uid'] = data['uid'].astype(str)
data['Class'] = data['Class'].astype(str)

uids = data['uid'].values
classes = data['Class'].values

print(f"Balanced Data: {len(data)}")

logtxt += f"Balanced Data: {len(data)}\n"

indx_type_to_consider = np.where(
	np.array([(data['Class'] == source) for source in sources_to_consider]).any(axis=0)
)

print(f"{len(sources_to_consider)} sources to consider: {len(indx_type_to_consider[0])}")
data = data.iloc[indx_type_to_consider[0]]

logtxt += f"Balanced: {len(sources_to_consider)} sources to consider: {len(indx_type_to_consider[0])}\n"
logtxt += "\n"
# Out:
# Balanced Data: 282753
# 10 sources to consider: 282753

# %%
import yaml
path_feature_config = os.path.join(CONFIG, "feature.yaml")

with open(path_feature_config, "r") as f:
    feature_config = yaml.safe_load(f)

feature_key = "Rubin+7DT_40"
all_features = feature_config[feature_key]['color']

# %%
color_7dt_features = feature_config["7DT_40"]["color"]

# %%
lsst_filters = ["u", "g", "r", "i", "z", "y"]

# %%
rubin_added_feature_dict = {}

for filte in lsst_filters:
    features = color_7dt_features.copy()
    for feature in all_features:
        if filte in feature:
            features.append(feature)
        else:
            pass
    rubin_added_feature_dict[filte] = features

# rubin_added_feature_dict

# %% [markdown]
# ## Train & Test Sample

# %%
# - Split features/target
X = data.drop(columns=['Sample_ID', 'Class', 'uid'])
y = data['Class']
X.fillna(-99, inplace=True)

# - Split into train/test using GroupShuffleSplit by uid
gss = GroupShuffleSplit(n_splits=1, test_size=test_size, random_state=random_state)
train_idx, test_idx = next(gss.split(X, y, groups=data['uid']))
X_train, X_test = X.iloc[train_idx], X.iloc[test_idx]
y_train, y_test = y.iloc[train_idx], y.iloc[test_idx]

from xgboost import XGBClassifier, DMatrix

# - Label encode class for ML
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)
y_train_encoded = label_encoder.fit_transform(y_train)
y_test_encoded = label_encoder.transform(y_test)
class_names = np.array([str(c) for c in label_encoder.inverse_transform(np.arange(len(label_encoder.classes_)))])
print("Balanced: Class mapping:", class_names)

import xgboost as xgb
train_data = xgb.DMatrix(X_train, label=y_train_encoded)
test_data = xgb.DMatrix(X_test, label=y_test_encoded)
# Out:
# Balanced: Class mapping: ['AGN' 'CV' 'II' 'Ia' 'Ibc' 'LBV' 'M dwarf' 'Nova' 'SLSN' 'TDE']

# %%
del data

# %%
import yaml

# YAML 파일 열기
with open(f"../model/XGBoost_Fine_Tune/best_params.yaml", "r") as f:
    best_params = yaml.safe_load(f)

# 출력
# best_params['num_threads'] = 5
# best_params['task_type'] = 'GPU'
best_params['devices'] = 'cuda'
best_params
# Out:
# {'colsample_bytree': 0.8267500788217794,
#  'gamma': 0.44209594451199286,
#  'learning_rate': 0.28864022968866265,
#  'max_depth': 3,
#  'min_child_weight': 1,
#  'n_estimators': 1333,
#  'reg_lambda': 62.20766214503429,
#  'subsample': 0.9996711775883176,
#  'random_state': 42,
#  'devices': 'cuda'}

# %% [markdown]
# # Train and Evaluation

# %%
# X_train
# filte = 'u'

# feature_to_use = rubin_added_feature_dict[filte]
# X_train_sub = X_train[feature_to_use]
# X_test_sub = X_test[feature_to_use]

# %%
from xgboost import XGBClassifier

# best_model = XGBClassifier(**best_params)
# best_model.fit(
#     X_train_sub, y_train_encoded,
#     )
# y_pred = best_model.predict(X_test_sub)

# %%
import joblib  # for XGBoost and LightGBM

# # ---------------------
# # xgboost 저장
# # ---------------------
# best_model.save_model(os.path.join(path_save, f"xgboost_7DT_Rubin_{filte}.txt"))

# # ---------------------
# # XGBoost 저장
# # ---------------------
# best_model.save_model(os.path.join(path_save, f"xgboost_7DT_Rubin_{filte}.json"))  # .json preferred over .txt

# # ---------------------
# # LightGBM 저장
# # ---------------------
# joblib.dump(best_model, os.path.join(path_save, f"lightgbm_7DT_Rubin_{filte}.pkl"))

# %%
from sklearn.metrics import classification_report
import pandas as pd

# report_dict = classification_report(y_test, y_pred, target_names=class_names, output_dict=True)

# # 2. accuracy는 scalar → 딕셔너리로 따로 저장
# acc_value = report_dict.pop("accuracy")

# # 3. DataFrame으로 변환
# report_df = pd.DataFrame(report_dict).T  # class별 성능 포함

# # 4. accuracy row 추가 (f1-score 칸만 채움)
# report_df.loc["accuracy"] = [None, None, acc_value, report_df["support"].sum()]

# report_df.to_csv(os.path.join(path_save, f"classification_report_{filte}.csv"))

# %%
def plot_confusion_matrix():
    import seaborn as sns
    cm = confusion_matrix(y_test_encoded, y_pred)
    labels = label_encoder.classes_
    cm_percent = (cm / cm.sum(axis=1, keepdims=True)) * 100
    n_rows, n_cols = cm.shape
    combined_matrix = np.empty_like(cm, dtype=object)
    for i in range(n_rows):
        for j in range(n_cols):
            n = cm[i, j]
            p = cm_percent[i, j]
            combined_matrix[i, j] = f"{n:,}\n({p:.1f}%)"
    plt.figure(figsize=(12, 9))
    ax = sns.heatmap(cm_percent, annot=False, fmt="", cmap="Blues",
                        xticklabels=labels, yticklabels=labels,
                        cbar_kws={'label': '[%]'}, vmin=0, vmax=100)
    plt.xlabel("Predicted Label", fontsize=16)
    plt.ylabel("True Label", fontsize=16)
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
    # plt.title(__class__.__name__.replace("Experiment", ""))
    plt.tight_layout()
    thresh = 50
    for i in range(n_rows):
        for j in range(n_cols):
            value = cm_percent[i, j]
            text_color = "white" if value > thresh else "black"
            ax.text(j+0.5, i+0.5, combined_matrix[i, j], ha='center', va='center', color=text_color, fontsize=14)
    # plt.savefig(os.path.join(path_save, f"{__class__.__name__.lower()}_confusion_matrix.png"))

# plot_confusion_matrix()

# plt.savefig(os.path.join(path_save, f'confusion_matrix_{filte}.png'))

# %%
# cm = confusion_matrix(y_test, y_pred)
# df_cm = pd.DataFrame(cm, index=class_names, columns=class_names)
# df_cm

# df_cm.to_csv(os.path.join(path_save, f'confusion_matrix_{filte}.csv'))

# %%
import joblib
from sklearn.model_selection import GroupKFold
from sklearn.metrics import f1_score, classification_report

# # 설정
# class_names = label_encoder.classes_
# groups = uids
# gkf = GroupKFold(n_splits=5)

# cv_macro_f1_scores = []
# cv_per_class_f1_scores = []

# # 저장 경로 생성
# os.makedirs(path_save, exist_ok=True)

# Perform Grouped K-Fold Cross-Validation
"""
for fold, (train_idx, val_idx) in enumerate(gkf.split(X, y_encoded, groups=groups)):

    X_train_cv, X_val_cv = X.iloc[train_idx], X.iloc[val_idx]
    y_train_cv, y_val_cv = y_encoded[train_idx], y_encoded[val_idx]

    model_cv = LGBMClassifier(**best_params)
    model_cv.fit(
        X_train_cv, y_train_cv,
        eval_set=[(X_val_cv, y_val_cv)],
        # verbose=False
    )

    y_pred = model_cv.predict(X_val_cv)

    # === 1. Macro F1 저장 ===
    macro_f1 = f1_score(y_val_cv, y_pred, average='macro')
    cv_macro_f1_scores.append({'fold': fold, 'f1_macro': macro_f1})

    # === 2. Per-class F1 저장 ===
    report = classification_report(y_val_cv, y_pred, output_dict=True, zero_division=0)
    per_class_f1 = {label: report[str(i)]['f1-score'] for i, label in enumerate(class_names)}
    per_class_f1['fold'] = fold
    cv_per_class_f1_scores.append(per_class_f1)

    # === 3. 모델 저장 ===
    model_path = os.path.join(path_save, f"model_fold{fold}.pkl")
    joblib.dump(model_cv, model_path)

    # === 4. 리포트 출력 ===
    print(f"[Fold {fold}] f1_macro = {macro_f1:.4f}")

# === 5. 최종 결과 저장 ===
macro_f1_df = pd.DataFrame(cv_macro_f1_scores)
per_class_f1_df = pd.DataFrame(cv_per_class_f1_scores)

macro_f1_df.to_csv(os.path.join(path_save, f"cv_macro_f1_scores_{filte}.csv"), index=False)
per_class_f1_df.to_csv(os.path.join(path_save, f"cv_per_class_f1_scores_{filte}.csv"), index=False)"""
# Out:
# '\nfor fold, (train_idx, val_idx) in enumerate(gkf.split(X, y_encoded, groups=groups)):\n\n    X_train_cv, X_val_cv = X.iloc[train_idx], X.iloc[val_idx]\n    y_train_cv, y_val_cv = y_encoded[train_idx], y_encoded[val_idx]\n\n    model_cv = LGBMClassifier(**best_params)\n    model_cv.fit(\n        X_train_cv, y_train_cv,\n        eval_set=[(X_val_cv, y_val_cv)],\n        # verbose=False\n    )\n\n    y_pred = model_cv.predict(X_val_cv)\n\n    # === 1. Macro F1 저장 ===\n    macro_f1 = f1_score(y_val_cv, y_pred, average=\'macro\')\n    cv_macro_f1_scores.append({\'fold\': fold, \'f1_macro\': macro_f1})\n\n    # === 2. Per-class F1 저장 ===\n    report = classification_report(y_val_cv, y_pred, output_dict=True, zero_division=0)\n    per_class_f1 = {label: report[str(i)][\'f1-score\'] for i, label in enumerate(class_names)}\n    per_class_f1[\'fold\'] = fold\n    cv_per_class_f1_scores.append(per_class_f1)\n\n    # === 3. 모델 저장 ===\n    model_path = os.path.join(path_save, f"model_fold{fold}.pkl")\n    joblib.dump(model_cv, model_path)\n\n    # === 4. 리포트 출력 ===\n    print(f"[Fold {fold}] f1_macro = {macro_f1:.4f}")\n\n# === 5. 최종 결과 저장 ===\nmacro_f1_df = pd.DataFrame(cv_macro_f1_scores)\nper_class_f1_df = pd.DataFrame(cv_per_class_f1_scores)\n\nmacro_f1_df.to_csv(os.path.join(path_save, f"cv_macro_f1_scores_{filte}.csv"), index=False)\nper_class_f1_df.to_csv(os.path.join(path_save, f"cv_per_class_f1_scores_{filte}.csv"), index=False)'

# %%
test_name = "Rubin_7DT_xgboost"
path_save = os.path.join(MODEL, test_name)
os.makedirs(path_save, exist_ok=True)

import joblib  # for XGBoost and LightGBM
import pandas as pd
import joblib
from sklearn.model_selection import GroupKFold
from sklearn.metrics import f1_score, classification_report

for filte in lsst_filters:
    print(f"FILTER: {filte}")

    df_cm_filename = os.path.join(path_save, f'confusion_matrix_{filte}.csv')
    
    feature_to_use = rubin_added_feature_dict[filte]
    X_sub = X[feature_to_use]
    X_train_sub = X_train[feature_to_use]
    X_test_sub = X_test[feature_to_use]

    if not os.path.exists(df_cm_filename):
        #
        print(f"Start Training")
        best_model = XGBClassifier(**best_params)
        best_model.fit(
            X_train_sub, y_train_encoded,
            )
        y_pred = best_model.predict(X_test_sub)
        # best_model.save_model(f"{path_save}/best_lightgbm_model.txt")
        #
        
        best_model.save_model(os.path.join(path_save, f"xgboost_7DT_Rubin_{filte}.json"))  # .json preferred over .txt
    
    
        print(f"Get Classification Report")
        report_dict = classification_report(y_test_encoded, y_pred, target_names=class_names, output_dict=True)
        
        # 2. accuracy는 scalar → 딕셔너리로 따로 저장
        acc_value = report_dict.pop("accuracy")
        
        # 3. DataFrame으로 변환
        report_df = pd.DataFrame(report_dict).T  # class별 성능 포함
        
        # 4. accuracy row 추가 (f1-score 칸만 채움)
        report_df.loc["accuracy"] = [None, None, acc_value, report_df["support"].sum()]
        report_df.to_csv(os.path.join(path_save, f"classification_report_{filte}.csv"))
    
        print(f"Get Confusion Matrix")
        plot_confusion_matrix()
        plt.savefig(os.path.join(path_save, f'confusion_matrix_{filte}.png'))
        plt.close()
        
        cm = confusion_matrix(y_test_encoded, y_pred)
        df_cm = pd.DataFrame(cm, index=class_names, columns=class_names)
        df_cm.to_csv(os.path.join(path_save, f'confusion_matrix_{filte}.csv'))
    
    else:
        print(df_cm_filename, "exists")
        
    # 설정
    class_names = label_encoder.classes_
    groups = uids
    gkf = GroupKFold(n_splits=5)
    
    cv_macro_f1_scores = []
    cv_per_class_f1_scores = []
    
    # 저장 경로 생성
    print(f"Calculate 5-Fold Cross-Validation Values")

    # Perform Grouped K-Fold Cross-Validation
    for fold, (train_idx, val_idx) in enumerate(gkf.split(X, y_encoded, groups=groups)):

        macro_f1_df_filename = os.path.join(path_save, f"cv_macro_f1_scores_{filte}_{fold}.csv")
        per_class_f1_df_filename = os.path.join(path_save, f"cv_per_class_f1_scores_{filte}_{fold}.csv")

        if (not os.path.exists(macro_f1_df_filename)) & ((not os.path.exists(per_class_f1_df_filename))):
    
            
            X_train_cv, X_val_cv = X_sub.iloc[train_idx], X_sub.iloc[val_idx]
            y_train_cv, y_val_cv = y_encoded[train_idx], y_encoded[val_idx]
        
            model_cv = XGBClassifier(**best_params)
            model_cv.fit(
                X_train_cv, y_train_cv,
                eval_set=[(X_val_cv, y_val_cv)],
                # verbose=False
            )
        
            y_pred = model_cv.predict(X_val_cv)
        
            # === 1. Macro F1 저장 ===
            macro_f1 = f1_score(y_val_cv, y_pred, average='macro')
            cv_macro_f1_scores.append({'fold': fold, 'f1_macro': macro_f1})
        
            # === 2. Per-class F1 저장 ===
            report = classification_report(y_val_cv, y_pred, output_dict=True, zero_division=0)
            per_class_f1 = {label: report[str(i)]['f1-score'] for i, label in enumerate(class_names)}
            per_class_f1['fold'] = fold
            cv_per_class_f1_scores.append(per_class_f1)
        
            # === 3. 모델 저장 ===
            model_path = os.path.join(path_save, f"model_fold{fold}.pkl")
            joblib.dump(model_cv, model_path)
        
            # === 4. 리포트 출력 ===
            print(f"[Fold {fold}] f1_macro = {macro_f1:.3f}")
            
            # === 5. 최종 결과 저장 ===
            macro_f1_df = pd.DataFrame(cv_macro_f1_scores)
            per_class_f1_df = pd.DataFrame(cv_per_class_f1_scores)
            
            macro_f1_df.to_csv(macro_f1_df_filename, index=False)
            per_class_f1_df.to_csv(per_class_f1_df_filename, index=False)
        else:
            print(macro_f1_df_filename, "exists")
            print(per_class_f1_df_filename, "exists")
# Out:
# FILTER: u
# /home/gpaek/SED-Classifier/notebook/../model/Rubin_7DT_xgboost/confusion_matrix_u.csv exists
# Calculate 5-Fold Cross-Validation Values
# [0]	validation_0-mlogloss:1.89016
# [1]	validation_0-mlogloss:1.67574
# [2]	validation_0-mlogloss:1.52495
# [3]	validation_0-mlogloss:1.41345
# [4]	validation_0-mlogloss:1.32417
# [5]	validation_0-mlogloss:1.25467
# [6]	validation_0-mlogloss:1.19976
# [7]	validation_0-mlogloss:1.15094
# [8]	validation_0-mlogloss:1.11100
# [9]	validation_0-mlogloss:1.07654
# [10]	validation_0-mlogloss:1.05153
# [11]	validation_0-mlogloss:1.03331
# [12]	validation_0-mlogloss:1.01181
# [13]	validation_0-mlogloss:0.99813
# [14]	validation_0-mlogloss:0.98715
# [15]	validation_0-mlogloss:0.97414
# [16]	validation_0-mlogloss:0.96768
# [17]	validation_0-mlogloss:0.95771
# [18]	validation_0-mlogloss:0.95402
# [19]	validation_0-mlogloss:0.94327
# [20]	validation_0-mlogloss:0.93547
# [21]	validation_0-mlogloss:0.93406
# [22]	validation_0-mlogloss:0.93503
# [23]	validation_0-mlogloss:0.92997
# [24]	validation_0-mlogloss:0.92638
# [25]	validation_0-mlogloss:0.92636
# [26]	validation_0-mlogloss:0.92241
# [27]	validation_0-mlogloss:0.92194
# [28]	validation_0-mlogloss:0.92031
# [29]	validation_0-mlogloss:0.92247
# [30]	validation_0-mlogloss:0.92277
# [31]	validation_0-mlogloss:0.92418
# [32]	validation_0-mlogloss:0.92246
# [33]	validation_0-mlogloss:0.92616
# [34]	validation_0-mlogloss:0.92591
# [35]	validation_0-mlogloss:0.92693
# [36]	validation_0-mlogloss:0.92674
# [37]	validation_0-mlogloss:0.92728
# [38]	validation_0-mlogloss:0.92469
# [39]	validation_0-mlogloss:0.92943
# [40]	validation_0-mlogloss:0.92955
# [41]	validation_0-mlogloss:0.92754
# [42]	validation_0-mlogloss:0.93000
# [43]	validation_0-mlogloss:0.92924
# [44]	validation_0-mlogloss:0.93070
# [45]	validation_0-mlogloss:0.93412
# [46]	validation_0-mlogloss:0.93213
# [47]	validation_0-mlogloss:0.93297
# [48]	validation_0-mlogloss:0.92906
# [49]	validation_0-mlogloss:0.92937
# [50]	validation_0-mlogloss:0.92807
# [51]	validation_0-mlogloss:0.92987
# [52]	validation_0-mlogloss:0.92993
# [53]	validation_0-mlogloss:0.93029
# [54]	validation_0-mlogloss:0.92970
# [55]	validation_0-mlogloss:0.93269
# [56]	validation_0-mlogloss:0.93428
# [57]	validation_0-mlogloss:0.93592
# [58]	validation_0-mlogloss:0.93713
# [59]	validation_0-mlogloss:0.93782
# [60]	validation_0-mlogloss:0.93759
# [61]	validation_0-mlogloss:0.93968
# [62]	validation_0-mlogloss:0.94095
# [63]	validation_0-mlogloss:0.94149
# [64]	validation_0-mlogloss:0.94482
# [65]	validation_0-mlogloss:0.94516
# [66]	validation_0-mlogloss:0.94674
# [67]	validation_0-mlogloss:0.94667
# [68]	validation_0-mlogloss:0.94578
# [69]	validation_0-mlogloss:0.94810
# [70]	validation_0-mlogloss:0.94987
# [71]	validation_0-mlogloss:0.94908
# [72]	validation_0-mlogloss:0.94840
# [73]	validation_0-mlogloss:0.94881
# [74]	validation_0-mlogloss:0.94896
# [75]	validation_0-mlogloss:0.95026
# [76]	validation_0-mlogloss:0.95051
# [77]	validation_0-mlogloss:0.94896
# [78]	validation_0-mlogloss:0.95013
# [79]	validation_0-mlogloss:0.95298
# [80]	validation_0-mlogloss:0.95440
# [81]	validation_0-mlogloss:0.95498
# [82]	validation_0-mlogloss:0.95706
# [83]	validation_0-mlogloss:0.95703
# [84]	validation_0-mlogloss:0.95775
# [85]	validation_0-mlogloss:0.95865
# [86]	validation_0-mlogloss:0.95901
# [87]	validation_0-mlogloss:0.95952
# [88]	validation_0-mlogloss:0.96035
# [89]	validation_0-mlogloss:0.96047
# [90]	validation_0-mlogloss:0.96170
# [91]	validation_0-mlogloss:0.96378
# [92]	validation_0-mlogloss:0.96116
# [93]	validation_0-mlogloss:0.96061
# [94]	validation_0-mlogloss:0.96115
# [95]	validation_0-mlogloss:0.96035
# [96]	validation_0-mlogloss:0.95781
# [97]	validation_0-mlogloss:0.96003
# [98]	validation_0-mlogloss:0.96106
# [99]	validation_0-mlogloss:0.96392
# [100]	validation_0-mlogloss:0.96403
# [101]	validation_0-mlogloss:0.96506
# [102]	validation_0-mlogloss:0.96554
# [103]	validation_0-mlogloss:0.96629
# [104]	validation_0-mlogloss:0.96674
# [105]	validation_0-mlogloss:0.96607
# [106]	validation_0-mlogloss:0.96653
# [107]	validation_0-mlogloss:0.96817
# [108]	validation_0-mlogloss:0.96673
# [109]	validation_0-mlogloss:0.96744
# [110]	validation_0-mlogloss:0.96616
# [111]	validation_0-mlogloss:0.96691
# [112]	validation_0-mlogloss:0.96705
# [113]	validation_0-mlogloss:0.96855
# [114]	validation_0-mlogloss:0.96794
# [115]	validation_0-mlogloss:0.97001
# [116]	validation_0-mlogloss:0.97175
# [117]	validation_0-mlogloss:0.97092
# [118]	validation_0-mlogloss:0.97133
# [119]	validation_0-mlogloss:0.97038
# [120]	validation_0-mlogloss:0.97118
# [121]	validation_0-mlogloss:0.97044
# [122]	validation_0-mlogloss:0.97161
# [123]	validation_0-mlogloss:0.97116
# [124]	validation_0-mlogloss:0.97207
# [125]	validation_0-mlogloss:0.97371
# [126]	validation_0-mlogloss:0.97340
# [127]	validation_0-mlogloss:0.97265
# [128]	validation_0-mlogloss:0.97170
# [129]	validation_0-mlogloss:0.97312
# [130]	validation_0-mlogloss:0.97201
# [131]	validation_0-mlogloss:0.97129
# [132]	validation_0-mlogloss:0.96965
# [133]	validation_0-mlogloss:0.96842
# [134]	validation_0-mlogloss:0.96880
# [135]	validation_0-mlogloss:0.96777
# [136]	validation_0-mlogloss:0.97036
# [137]	validation_0-mlogloss:0.97190
# [138]	validation_0-mlogloss:0.97192
# [139]	validation_0-mlogloss:0.97091
# [140]	validation_0-mlogloss:0.97149
# [141]	validation_0-mlogloss:0.97023
# [142]	validation_0-mlogloss:0.97136
# [143]	validation_0-mlogloss:0.97028
# [144]	validation_0-mlogloss:0.97037
# [145]	validation_0-mlogloss:0.97101
# [146]	validation_0-mlogloss:0.97149
# [147]	validation_0-mlogloss:0.97138
# [148]	validation_0-mlogloss:0.97109
# [149]	validation_0-mlogloss:0.97227
# [150]	validation_0-mlogloss:0.97279
# [151]	validation_0-mlogloss:0.97262
# [152]	validation_0-mlogloss:0.97175
# [153]	validation_0-mlogloss:0.97172
# [154]	validation_0-mlogloss:0.97182
# [155]	validation_0-mlogloss:0.97168
# [156]	validation_0-mlogloss:0.97247
# [157]	validation_0-mlogloss:0.97335
# [158]	validation_0-mlogloss:0.97441
# [159]	validation_0-mlogloss:0.97333
# [160]	validation_0-mlogloss:0.97457
# [161]	validation_0-mlogloss:0.97409
# [162]	validation_0-mlogloss:0.97476
# [163]	validation_0-mlogloss:0.97381
# [164]	validation_0-mlogloss:0.97487
# [165]	validation_0-mlogloss:0.97450
# [166]	validation_0-mlogloss:0.97364
# [167]	validation_0-mlogloss:0.97364
# [168]	validation_0-mlogloss:0.97332
# [169]	validation_0-mlogloss:0.97349
# [170]	validation_0-mlogloss:0.97272
# [171]	validation_0-mlogloss:0.97427
# [172]	validation_0-mlogloss:0.97341
# [173]	validation_0-mlogloss:0.97463
# [174]	validation_0-mlogloss:0.97457
# [175]	validation_0-mlogloss:0.97477
# [176]	validation_0-mlogloss:0.97416
# [177]	validation_0-mlogloss:0.97487
# [178]	validation_0-mlogloss:0.97393
# [179]	validation_0-mlogloss:0.97418
# [180]	validation_0-mlogloss:0.97543
# [181]	validation_0-mlogloss:0.97611
# [182]	validation_0-mlogloss:0.97546
# [183]	validation_0-mlogloss:0.97526
# [184]	validation_0-mlogloss:0.97406
# [185]	validation_0-mlogloss:0.97401
# [186]	validation_0-mlogloss:0.97414
# [187]	validation_0-mlogloss:0.97446
# [188]	validation_0-mlogloss:0.97423
# [189]	validation_0-mlogloss:0.97428
# [190]	validation_0-mlogloss:0.97310
# [191]	validation_0-mlogloss:0.97183
# [192]	validation_0-mlogloss:0.97141
# [193]	validation_0-mlogloss:0.97016
# [194]	validation_0-mlogloss:0.97213
# [195]	validation_0-mlogloss:0.97433
# [196]	validation_0-mlogloss:0.97459
# [197]	validation_0-mlogloss:0.97442
# [198]	validation_0-mlogloss:0.97472
# [199]	validation_0-mlogloss:0.97509
# [200]	validation_0-mlogloss:0.97480
# [201]	validation_0-mlogloss:0.97456
# [202]	validation_0-mlogloss:0.97380
# [203]	validation_0-mlogloss:0.97436
# [204]	validation_0-mlogloss:0.97354
# [205]	validation_0-mlogloss:0.97257
# [206]	validation_0-mlogloss:0.97513
# [207]	validation_0-mlogloss:0.97497
# [208]	validation_0-mlogloss:0.97610
# [209]	validation_0-mlogloss:0.97783
# [210]	validation_0-mlogloss:0.97701
# [211]	validation_0-mlogloss:0.97745
# [212]	validation_0-mlogloss:0.97676
# [213]	validation_0-mlogloss:0.97649
# [214]	validation_0-mlogloss:0.97600
# [215]	validation_0-mlogloss:0.97591
# [216]	validation_0-mlogloss:0.97603
# [217]	validation_0-mlogloss:0.97669
# [218]	validation_0-mlogloss:0.97882
# [219]	validation_0-mlogloss:0.97849
# [220]	validation_0-mlogloss:0.97838
# [221]	validation_0-mlogloss:0.97783
# [222]	validation_0-mlogloss:0.97845
# [223]	validation_0-mlogloss:0.97841
# [224]	validation_0-mlogloss:0.97807
# [225]	validation_0-mlogloss:0.97840
# [226]	validation_0-mlogloss:0.97671
# [227]	validation_0-mlogloss:0.97796
# [228]	validation_0-mlogloss:0.98104
# [229]	validation_0-mlogloss:0.98100
# [230]	validation_0-mlogloss:0.98073
# [231]	validation_0-mlogloss:0.98105
# [232]	validation_0-mlogloss:0.98167
# [233]	validation_0-mlogloss:0.98163
# [234]	validation_0-mlogloss:0.98138
# [235]	validation_0-mlogloss:0.98081
# [236]	validation_0-mlogloss:0.98110
# [237]	validation_0-mlogloss:0.98233
# [238]	validation_0-mlogloss:0.98199
# [239]	validation_0-mlogloss:0.98332
# [240]	validation_0-mlogloss:0.98513
# [241]	validation_0-mlogloss:0.98535
# [242]	validation_0-mlogloss:0.98411
# [243]	validation_0-mlogloss:0.98326
# [244]	validation_0-mlogloss:0.98456
# [245]	validation_0-mlogloss:0.98392
# [246]	validation_0-mlogloss:0.98301
# [247]	validation_0-mlogloss:0.98365
# [248]	validation_0-mlogloss:0.98309
# [249]	validation_0-mlogloss:0.98121
# [250]	validation_0-mlogloss:0.98058
# [251]	validation_0-mlogloss:0.98132
# [252]	validation_0-mlogloss:0.98113
# [253]	validation_0-mlogloss:0.98188
# [254]	validation_0-mlogloss:0.98156
# [255]	validation_0-mlogloss:0.98135
# [256]	validation_0-mlogloss:0.98150
# [257]	validation_0-mlogloss:0.98243
# [258]	validation_0-mlogloss:0.98268
# [259]	validation_0-mlogloss:0.98313
# [260]	validation_0-mlogloss:0.98386
# [261]	validation_0-mlogloss:0.98286
# [262]	validation_0-mlogloss:0.98301
# [263]	validation_0-mlogloss:0.98427
# [264]	validation_0-mlogloss:0.98532
# [265]	validation_0-mlogloss:0.98662
# [266]	validation_0-mlogloss:0.98654
# [267]	validation_0-mlogloss:0.98755
# [268]	validation_0-mlogloss:0.98842
# [269]	validation_0-mlogloss:0.98742
# [270]	validation_0-mlogloss:0.98709
# [271]	validation_0-mlogloss:0.98819
# [272]	validation_0-mlogloss:0.98905
# [273]	validation_0-mlogloss:0.98999
# [274]	validation_0-mlogloss:0.99051
# [275]	validation_0-mlogloss:0.99062
# [276]	validation_0-mlogloss:0.99123
# [277]	validation_0-mlogloss:0.99239
# [278]	validation_0-mlogloss:0.99171
# [279]	validation_0-mlogloss:0.99024
# [280]	validation_0-mlogloss:0.99078
# [281]	validation_0-mlogloss:0.99111
# [282]	validation_0-mlogloss:0.99103
# [283]	validation_0-mlogloss:0.99242
# [284]	validation_0-mlogloss:0.99214
# [285]	validation_0-mlogloss:0.99233
# [286]	validation_0-mlogloss:0.99275
# [287]	validation_0-mlogloss:0.99291
# [288]	validation_0-mlogloss:0.99335
# [289]	validation_0-mlogloss:0.99330
# [290]	validation_0-mlogloss:0.99353
# [291]	validation_0-mlogloss:0.99429
# [292]	validation_0-mlogloss:0.99336
# [293]	validation_0-mlogloss:0.99389
# [294]	validation_0-mlogloss:0.99327
# [295]	validation_0-mlogloss:0.99311
# [296]	validation_0-mlogloss:0.99404
# [297]	validation_0-mlogloss:0.99370
# [298]	validation_0-mlogloss:0.99379
# [299]	validation_0-mlogloss:0.99406
# [300]	validation_0-mlogloss:0.99469
# [301]	validation_0-mlogloss:0.99492
# [302]	validation_0-mlogloss:0.99499
# [303]	validation_0-mlogloss:0.99530
# [304]	validation_0-mlogloss:0.99468
# [305]	validation_0-mlogloss:0.99603
# [306]	validation_0-mlogloss:0.99550
# [307]	validation_0-mlogloss:0.99612
# [308]	validation_0-mlogloss:0.99577
# [309]	validation_0-mlogloss:0.99604
# [310]	validation_0-mlogloss:0.99747
# [311]	validation_0-mlogloss:0.99774
# [312]	validation_0-mlogloss:0.99797
# [313]	validation_0-mlogloss:0.99871
# [314]	validation_0-mlogloss:0.99951
# [315]	validation_0-mlogloss:0.99969
# [316]	validation_0-mlogloss:1.00028
# [317]	validation_0-mlogloss:0.99952
# [318]	validation_0-mlogloss:0.99921
# [319]	validation_0-mlogloss:0.99782
# [320]	validation_0-mlogloss:0.99756
# [321]	validation_0-mlogloss:0.99746
# [322]	validation_0-mlogloss:0.99739
# [323]	validation_0-mlogloss:0.99723
# [324]	validation_0-mlogloss:0.99753
# [325]	validation_0-mlogloss:0.99626
# [326]	validation_0-mlogloss:0.99936
# [327]	validation_0-mlogloss:0.99912
# [328]	validation_0-mlogloss:0.99940
# [329]	validation_0-mlogloss:0.99945
# [330]	validation_0-mlogloss:1.00098
# [331]	validation_0-mlogloss:1.00076
# [332]	validation_0-mlogloss:1.00088
# [333]	validation_0-mlogloss:1.00003
# [334]	validation_0-mlogloss:0.99997
# [335]	validation_0-mlogloss:0.99986
# [336]	validation_0-mlogloss:0.99913
# [337]	validation_0-mlogloss:1.00051
# [338]	validation_0-mlogloss:1.00083
# [339]	validation_0-mlogloss:1.00148
# [340]	validation_0-mlogloss:1.00101
# [341]	validation_0-mlogloss:1.00122
# [342]	validation_0-mlogloss:1.00146
# [343]	validation_0-mlogloss:1.00161
# [344]	validation_0-mlogloss:1.00192
# [345]	validation_0-mlogloss:1.00327
# [346]	validation_0-mlogloss:1.00342
# [347]	validation_0-mlogloss:1.00345
# [348]	validation_0-mlogloss:1.00384
# [349]	validation_0-mlogloss:1.00249
# [350]	validation_0-mlogloss:1.00277
# [351]	validation_0-mlogloss:1.00171
# [352]	validation_0-mlogloss:1.00255
# [353]	validation_0-mlogloss:1.00196
# [354]	validation_0-mlogloss:1.00145
# [355]	validation_0-mlogloss:1.00203
# [356]	validation_0-mlogloss:1.00287
# [357]	validation_0-mlogloss:1.00282
# [358]	validation_0-mlogloss:1.00297
# [359]	validation_0-mlogloss:1.00252
# [360]	validation_0-mlogloss:1.00327
# [361]	validation_0-mlogloss:1.00407
# [362]	validation_0-mlogloss:1.00423
# [363]	validation_0-mlogloss:1.00461
# [364]	validation_0-mlogloss:1.00455
# [365]	validation_0-mlogloss:1.00433
# [366]	validation_0-mlogloss:1.00342
# [367]	validation_0-mlogloss:1.00490
# [368]	validation_0-mlogloss:1.00415
# [369]	validation_0-mlogloss:1.00517
# [370]	validation_0-mlogloss:1.00617
# [371]	validation_0-mlogloss:1.00608
# [372]	validation_0-mlogloss:1.00513
# [373]	validation_0-mlogloss:1.00531
# [374]	validation_0-mlogloss:1.00534
# [375]	validation_0-mlogloss:1.00601
# [376]	validation_0-mlogloss:1.00567
# [377]	validation_0-mlogloss:1.00497
# [378]	validation_0-mlogloss:1.00574
# [379]	validation_0-mlogloss:1.00617
# [380]	validation_0-mlogloss:1.00575
# [381]	validation_0-mlogloss:1.00542
# [382]	validation_0-mlogloss:1.00554
# [383]	validation_0-mlogloss:1.00594
# [384]	validation_0-mlogloss:1.00605
# [385]	validation_0-mlogloss:1.00484
# [386]	validation_0-mlogloss:1.00532
# [387]	validation_0-mlogloss:1.00601
# [388]	validation_0-mlogloss:1.00563
# [389]	validation_0-mlogloss:1.00488
# [390]	validation_0-mlogloss:1.00452
# [391]	validation_0-mlogloss:1.00394
# [392]	validation_0-mlogloss:1.00407
# [393]	validation_0-mlogloss:1.00433
# [394]	validation_0-mlogloss:1.00461
# [395]	validation_0-mlogloss:1.00593
# [396]	validation_0-mlogloss:1.00639
# [397]	validation_0-mlogloss:1.00723
# [398]	validation_0-mlogloss:1.00745
# [399]	validation_0-mlogloss:1.00670
# [400]	validation_0-mlogloss:1.00731
# [401]	validation_0-mlogloss:1.00607
# [402]	validation_0-mlogloss:1.00598
# [403]	validation_0-mlogloss:1.00714
# [404]	validation_0-mlogloss:1.00830
# [405]	validation_0-mlogloss:1.00707
# [406]	validation_0-mlogloss:1.00657
# [407]	validation_0-mlogloss:1.00701
# [408]	validation_0-mlogloss:1.00723
# [409]	validation_0-mlogloss:1.00781
# [410]	validation_0-mlogloss:1.00729
# [411]	validation_0-mlogloss:1.00732
# [412]	validation_0-mlogloss:1.00934
# [413]	validation_0-mlogloss:1.00983
# [414]	validation_0-mlogloss:1.01128
# [415]	validation_0-mlogloss:1.01091
# [416]	validation_0-mlogloss:1.01109
# [417]	validation_0-mlogloss:1.01166
# [418]	validation_0-mlogloss:1.01248
# [419]	validation_0-mlogloss:1.01399
# [420]	validation_0-mlogloss:1.01364
# [421]	validation_0-mlogloss:1.01421
# [422]	validation_0-mlogloss:1.01491
# [423]	validation_0-mlogloss:1.01521
# [424]	validation_0-mlogloss:1.01544
# [425]	validation_0-mlogloss:1.01557
# [426]	validation_0-mlogloss:1.01571
# [427]	validation_0-mlogloss:1.01674
# [428]	validation_0-mlogloss:1.01776
# [429]	validation_0-mlogloss:1.01849
# [430]	validation_0-mlogloss:1.01822
# [431]	validation_0-mlogloss:1.01864
# [432]	validation_0-mlogloss:1.01915
# [433]	validation_0-mlogloss:1.01946
# [434]	validation_0-mlogloss:1.02006
# [435]	validation_0-mlogloss:1.01990
# [436]	validation_0-mlogloss:1.01972
# [437]	validation_0-mlogloss:1.01992
# [438]	validation_0-mlogloss:1.02061
# [439]	validation_0-mlogloss:1.02147
# [440]	validation_0-mlogloss:1.02205
# [441]	validation_0-mlogloss:1.02119
# [442]	validation_0-mlogloss:1.02088
# [443]	validation_0-mlogloss:1.02127
# [444]	validation_0-mlogloss:1.02110
# [445]	validation_0-mlogloss:1.02087
# [446]	validation_0-mlogloss:1.02139
# [447]	validation_0-mlogloss:1.02116
# [448]	validation_0-mlogloss:1.02152
# [449]	validation_0-mlogloss:1.02064
# [450]	validation_0-mlogloss:1.01967
# [451]	validation_0-mlogloss:1.01911
# [452]	validation_0-mlogloss:1.01927
# [453]	validation_0-mlogloss:1.01904
# [454]	validation_0-mlogloss:1.01887
# [455]	validation_0-mlogloss:1.01912
# [456]	validation_0-mlogloss:1.01900
# [457]	validation_0-mlogloss:1.01955
# [458]	validation_0-mlogloss:1.02028
# [459]	validation_0-mlogloss:1.02031
# [460]	validation_0-mlogloss:1.01997
# [461]	validation_0-mlogloss:1.01965
# [462]	validation_0-mlogloss:1.01975
# [463]	validation_0-mlogloss:1.01970
# [464]	validation_0-mlogloss:1.01987
# [465]	validation_0-mlogloss:1.02000
# [466]	validation_0-mlogloss:1.02058
# [467]	validation_0-mlogloss:1.02074
# [468]	validation_0-mlogloss:1.02165
# [469]	validation_0-mlogloss:1.02133
# [470]	validation_0-mlogloss:1.02137
# [471]	validation_0-mlogloss:1.02194
# [472]	validation_0-mlogloss:1.02266
# [473]	validation_0-mlogloss:1.02298
# [474]	validation_0-mlogloss:1.02354
# [475]	validation_0-mlogloss:1.02367
# [476]	validation_0-mlogloss:1.02344
# [477]	validation_0-mlogloss:1.02382
# [478]	validation_0-mlogloss:1.02433
# [479]	validation_0-mlogloss:1.02377
# [480]	validation_0-mlogloss:1.02453
# [481]	validation_0-mlogloss:1.02398
# [482]	validation_0-mlogloss:1.02337
# [483]	validation_0-mlogloss:1.02339
# [484]	validation_0-mlogloss:1.02349
# [485]	validation_0-mlogloss:1.02325
# [486]	validation_0-mlogloss:1.02344
# [487]	validation_0-mlogloss:1.02393
# [488]	validation_0-mlogloss:1.02359
# [489]	validation_0-mlogloss:1.02401
# [490]	validation_0-mlogloss:1.02431
# [491]	validation_0-mlogloss:1.02374
# [492]	validation_0-mlogloss:1.02463
# [493]	validation_0-mlogloss:1.02504
# [494]	validation_0-mlogloss:1.02489
# [495]	validation_0-mlogloss:1.02496
# [496]	validation_0-mlogloss:1.02623
# [497]	validation_0-mlogloss:1.02629
# [498]	validation_0-mlogloss:1.02607
# [499]	validation_0-mlogloss:1.02668
# [500]	validation_0-mlogloss:1.02702
# [501]	validation_0-mlogloss:1.02656
# [502]	validation_0-mlogloss:1.02639
# [503]	validation_0-mlogloss:1.02712
# [504]	validation_0-mlogloss:1.02711
# [505]	validation_0-mlogloss:1.02794
# [506]	validation_0-mlogloss:1.02799
# [507]	validation_0-mlogloss:1.02838
# [508]	validation_0-mlogloss:1.02846
# [509]	validation_0-mlogloss:1.02823
# [510]	validation_0-mlogloss:1.02822
# [511]	validation_0-mlogloss:1.02866
# [512]	validation_0-mlogloss:1.02977
# [513]	validation_0-mlogloss:1.02990
# [514]	validation_0-mlogloss:1.02981
# [515]	validation_0-mlogloss:1.02959
# [516]	validation_0-mlogloss:1.02991
# [517]	validation_0-mlogloss:1.02963
# [518]	validation_0-mlogloss:1.02930
# [519]	validation_0-mlogloss:1.02970
# [520]	validation_0-mlogloss:1.03075
# [521]	validation_0-mlogloss:1.03241
# [522]	validation_0-mlogloss:1.03212
# [523]	validation_0-mlogloss:1.03403
# [524]	validation_0-mlogloss:1.03373
# [525]	validation_0-mlogloss:1.03306
# [526]	validation_0-mlogloss:1.03248
# [527]	validation_0-mlogloss:1.03283
# [528]	validation_0-mlogloss:1.03326
# [529]	validation_0-mlogloss:1.03306
# [530]	validation_0-mlogloss:1.03349
# [531]	validation_0-mlogloss:1.03273
# [532]	validation_0-mlogloss:1.03226
# [533]	validation_0-mlogloss:1.03176
# [534]	validation_0-mlogloss:1.03120
# [535]	validation_0-mlogloss:1.03254
# [536]	validation_0-mlogloss:1.03322
# [537]	validation_0-mlogloss:1.03286
# [538]	validation_0-mlogloss:1.03316
# [539]	validation_0-mlogloss:1.03368
# [540]	validation_0-mlogloss:1.03406
# [541]	validation_0-mlogloss:1.03422
# [542]	validation_0-mlogloss:1.03419
# [543]	validation_0-mlogloss:1.03474
# [544]	validation_0-mlogloss:1.03481
# [545]	validation_0-mlogloss:1.03516
# [546]	validation_0-mlogloss:1.03437
# [547]	validation_0-mlogloss:1.03440
# [548]	validation_0-mlogloss:1.03412
# [549]	validation_0-mlogloss:1.03406
# [550]	validation_0-mlogloss:1.03412
# [551]	validation_0-mlogloss:1.03453
# [552]	validation_0-mlogloss:1.03433
# [553]	validation_0-mlogloss:1.03416
# [554]	validation_0-mlogloss:1.03337
# [555]	validation_0-mlogloss:1.03318
# [556]	validation_0-mlogloss:1.03316
# [557]	validation_0-mlogloss:1.03278
# [558]	validation_0-mlogloss:1.03380
# [559]	validation_0-mlogloss:1.03374
# [560]	validation_0-mlogloss:1.03393
# [561]	validation_0-mlogloss:1.03326
# [562]	validation_0-mlogloss:1.03375
# [563]	validation_0-mlogloss:1.03358
# [564]	validation_0-mlogloss:1.03413
# [565]	validation_0-mlogloss:1.03488
# [566]	validation_0-mlogloss:1.03480
# [567]	validation_0-mlogloss:1.03480
# [568]	validation_0-mlogloss:1.03471
# [569]	validation_0-mlogloss:1.03528
# [570]	validation_0-mlogloss:1.03666
# [571]	validation_0-mlogloss:1.03675
# [572]	validation_0-mlogloss:1.03668
# [573]	validation_0-mlogloss:1.03702
# [574]	validation_0-mlogloss:1.03694
# [575]	validation_0-mlogloss:1.03760
# [576]	validation_0-mlogloss:1.03847
# [577]	validation_0-mlogloss:1.03869
# [578]	validation_0-mlogloss:1.03904
# [579]	validation_0-mlogloss:1.03894
# [580]	validation_0-mlogloss:1.03876
# [581]	validation_0-mlogloss:1.03867
# [582]	validation_0-mlogloss:1.03877
# [583]	validation_0-mlogloss:1.03920
# [584]	validation_0-mlogloss:1.03903
# [585]	validation_0-mlogloss:1.03843
# [586]	validation_0-mlogloss:1.03861
# [587]	validation_0-mlogloss:1.03853
# [588]	validation_0-mlogloss:1.03870
# [589]	validation_0-mlogloss:1.03858
# [590]	validation_0-mlogloss:1.03882
# [591]	validation_0-mlogloss:1.03879
# [592]	validation_0-mlogloss:1.03858
# [593]	validation_0-mlogloss:1.03908
# [594]	validation_0-mlogloss:1.03917
# [595]	validation_0-mlogloss:1.03936
# [596]	validation_0-mlogloss:1.03952
# [597]	validation_0-mlogloss:1.03936
# [598]	validation_0-mlogloss:1.03904
# [599]	validation_0-mlogloss:1.03893
# [600]	validation_0-mlogloss:1.03860
# [601]	validation_0-mlogloss:1.03953
# [602]	validation_0-mlogloss:1.03975
# [603]	validation_0-mlogloss:1.04008
# [604]	validation_0-mlogloss:1.04005
# [605]	validation_0-mlogloss:1.03940
# [606]	validation_0-mlogloss:1.03955
# [607]	validation_0-mlogloss:1.03963
# [608]	validation_0-mlogloss:1.03993
# [609]	validation_0-mlogloss:1.04030
# [610]	validation_0-mlogloss:1.03968
# [611]	validation_0-mlogloss:1.04010
# [612]	validation_0-mlogloss:1.04051
# [613]	validation_0-mlogloss:1.04075
# [614]	validation_0-mlogloss:1.04117
# [615]	validation_0-mlogloss:1.04093
# [616]	validation_0-mlogloss:1.04096
# [617]	validation_0-mlogloss:1.04210
# [618]	validation_0-mlogloss:1.04147
# [619]	validation_0-mlogloss:1.04189
# [620]	validation_0-mlogloss:1.04211
# [621]	validation_0-mlogloss:1.04189
# [622]	validation_0-mlogloss:1.04122
# [623]	validation_0-mlogloss:1.04151
# [624]	validation_0-mlogloss:1.04138
# [625]	validation_0-mlogloss:1.04120
# [626]	validation_0-mlogloss:1.04100
# [627]	validation_0-mlogloss:1.04101
# [628]	validation_0-mlogloss:1.04060
# [629]	validation_0-mlogloss:1.04159
# [630]	validation_0-mlogloss:1.04192
# [631]	validation_0-mlogloss:1.04176
# [632]	validation_0-mlogloss:1.04172
# [633]	validation_0-mlogloss:1.04185
# [634]	validation_0-mlogloss:1.04300
# [635]	validation_0-mlogloss:1.04247
# [636]	validation_0-mlogloss:1.04338
# [637]	validation_0-mlogloss:1.04332
# [638]	validation_0-mlogloss:1.04313
# [639]	validation_0-mlogloss:1.04371
# [640]	validation_0-mlogloss:1.04446
# [641]	validation_0-mlogloss:1.04419
# [642]	validation_0-mlogloss:1.04427
# [643]	validation_0-mlogloss:1.04399
# [644]	validation_0-mlogloss:1.04422
# [645]	validation_0-mlogloss:1.04293
# [646]	validation_0-mlogloss:1.04336
# [647]	validation_0-mlogloss:1.04315
# [648]	validation_0-mlogloss:1.04279
# [649]	validation_0-mlogloss:1.04274
# [650]	validation_0-mlogloss:1.04341
# [651]	validation_0-mlogloss:1.04367
# [652]	validation_0-mlogloss:1.04319
# [653]	validation_0-mlogloss:1.04309
# [654]	validation_0-mlogloss:1.04284
# [655]	validation_0-mlogloss:1.04334
# [656]	validation_0-mlogloss:1.04284
# [657]	validation_0-mlogloss:1.04305
# [658]	validation_0-mlogloss:1.04276
# [659]	validation_0-mlogloss:1.04307
# [660]	validation_0-mlogloss:1.04361
# [661]	validation_0-mlogloss:1.04404
# [662]	validation_0-mlogloss:1.04407
# [663]	validation_0-mlogloss:1.04461
# [664]	validation_0-mlogloss:1.04482
# [665]	validation_0-mlogloss:1.04500
# [666]	validation_0-mlogloss:1.04555
# [667]	validation_0-mlogloss:1.04668
# [668]	validation_0-mlogloss:1.04782
# [669]	validation_0-mlogloss:1.04825
# [670]	validation_0-mlogloss:1.04791
# [671]	validation_0-mlogloss:1.04794
# [672]	validation_0-mlogloss:1.04802
# [673]	validation_0-mlogloss:1.04810
# [674]	validation_0-mlogloss:1.04825
# [675]	validation_0-mlogloss:1.04894
# [676]	validation_0-mlogloss:1.04922
# [677]	validation_0-mlogloss:1.04927
# [678]	validation_0-mlogloss:1.04917
# [679]	validation_0-mlogloss:1.04929
# [680]	validation_0-mlogloss:1.04943
# [681]	validation_0-mlogloss:1.04837
# [682]	validation_0-mlogloss:1.04885
# [683]	validation_0-mlogloss:1.04829
# [684]	validation_0-mlogloss:1.04796
# [685]	validation_0-mlogloss:1.04754
# [686]	validation_0-mlogloss:1.04776
# [687]	validation_0-mlogloss:1.04794
# [688]	validation_0-mlogloss:1.04765
# [689]	validation_0-mlogloss:1.04810
# [690]	validation_0-mlogloss:1.04774
# [691]	validation_0-mlogloss:1.04742
# [692]	validation_0-mlogloss:1.04728
# [693]	validation_0-mlogloss:1.04771
# [694]	validation_0-mlogloss:1.04809
# [695]	validation_0-mlogloss:1.04887
# [696]	validation_0-mlogloss:1.04852
# [697]	validation_0-mlogloss:1.04848
# [698]	validation_0-mlogloss:1.04818
# [699]	validation_0-mlogloss:1.04844
# [700]	validation_0-mlogloss:1.04784
# [701]	validation_0-mlogloss:1.04789
# [702]	validation_0-mlogloss:1.04749
# [703]	validation_0-mlogloss:1.04695
# [704]	validation_0-mlogloss:1.04694
# [705]	validation_0-mlogloss:1.04683
# [706]	validation_0-mlogloss:1.04706
# [707]	validation_0-mlogloss:1.04743
# [708]	validation_0-mlogloss:1.04772
# [709]	validation_0-mlogloss:1.04777
# [710]	validation_0-mlogloss:1.04820
# [711]	validation_0-mlogloss:1.04870
# [712]	validation_0-mlogloss:1.04893
# [713]	validation_0-mlogloss:1.04959
# [714]	validation_0-mlogloss:1.04954
# [715]	validation_0-mlogloss:1.05079
# [716]	validation_0-mlogloss:1.05097
# [717]	validation_0-mlogloss:1.05156
# [718]	validation_0-mlogloss:1.05163
# [719]	validation_0-mlogloss:1.05147
# [720]	validation_0-mlogloss:1.05077
# [721]	validation_0-mlogloss:1.05094
# [722]	validation_0-mlogloss:1.05092
# [723]	validation_0-mlogloss:1.05186
# [724]	validation_0-mlogloss:1.05183
# [725]	validation_0-mlogloss:1.05211
# [726]	validation_0-mlogloss:1.05219
# [727]	validation_0-mlogloss:1.05217
# [728]	validation_0-mlogloss:1.05271
# [729]	validation_0-mlogloss:1.05262
# [730]	validation_0-mlogloss:1.05239
# [731]	validation_0-mlogloss:1.05171
# [732]	validation_0-mlogloss:1.05194
# [733]	validation_0-mlogloss:1.05247
# [734]	validation_0-mlogloss:1.05270
# [735]	validation_0-mlogloss:1.05272
# [736]	validation_0-mlogloss:1.05227
# [737]	validation_0-mlogloss:1.05257
# [738]	validation_0-mlogloss:1.05243
# [739]	validation_0-mlogloss:1.05166
# [740]	validation_0-mlogloss:1.05152
# [741]	validation_0-mlogloss:1.05185
# [742]	validation_0-mlogloss:1.05225
# [743]	validation_0-mlogloss:1.05234
# [744]	validation_0-mlogloss:1.05245
# [745]	validation_0-mlogloss:1.05246
# [746]	validation_0-mlogloss:1.05205
# [747]	validation_0-mlogloss:1.05294
# [748]	validation_0-mlogloss:1.05259
# [749]	validation_0-mlogloss:1.05249
# [750]	validation_0-mlogloss:1.05226
# [751]	validation_0-mlogloss:1.05171
# [752]	validation_0-mlogloss:1.05151
# [753]	validation_0-mlogloss:1.05087
# [754]	validation_0-mlogloss:1.05076
# [755]	validation_0-mlogloss:1.05101
# [756]	validation_0-mlogloss:1.05054
# [757]	validation_0-mlogloss:1.05077
# [758]	validation_0-mlogloss:1.05103
# [759]	validation_0-mlogloss:1.05106
# [760]	validation_0-mlogloss:1.05127
# [761]	validation_0-mlogloss:1.05109
# [762]	validation_0-mlogloss:1.05108
# [763]	validation_0-mlogloss:1.05129
# [764]	validation_0-mlogloss:1.05121
# [765]	validation_0-mlogloss:1.05168
# [766]	validation_0-mlogloss:1.05177
# [767]	validation_0-mlogloss:1.05233
# [768]	validation_0-mlogloss:1.05217
# [769]	validation_0-mlogloss:1.05212
# [770]	validation_0-mlogloss:1.05250
# [771]	validation_0-mlogloss:1.05198
# [772]	validation_0-mlogloss:1.05202
# [773]	validation_0-mlogloss:1.05230
# [774]	validation_0-mlogloss:1.05195
# [775]	validation_0-mlogloss:1.05209
# [776]	validation_0-mlogloss:1.05190
# [777]	validation_0-mlogloss:1.05176
# [778]	validation_0-mlogloss:1.05169
# [779]	validation_0-mlogloss:1.05210
# [780]	validation_0-mlogloss:1.05265
# [781]	validation_0-mlogloss:1.05282
# [782]	validation_0-mlogloss:1.05252
# [783]	validation_0-mlogloss:1.05282
# [784]	validation_0-mlogloss:1.05227
# [785]	validation_0-mlogloss:1.05231
# [786]	validation_0-mlogloss:1.05236
# [787]	validation_0-mlogloss:1.05223
# [788]	validation_0-mlogloss:1.05227
# [789]	validation_0-mlogloss:1.05247
# [790]	validation_0-mlogloss:1.05262
# [791]	validation_0-mlogloss:1.05246
# [792]	validation_0-mlogloss:1.05247
# [793]	validation_0-mlogloss:1.05195
# [794]	validation_0-mlogloss:1.05287
# [795]	validation_0-mlogloss:1.05270
# [796]	validation_0-mlogloss:1.05289
# [797]	validation_0-mlogloss:1.05301
# [798]	validation_0-mlogloss:1.05276
# [799]	validation_0-mlogloss:1.05265
# [800]	validation_0-mlogloss:1.05271
# [801]	validation_0-mlogloss:1.05302
# [802]	validation_0-mlogloss:1.05293
# [803]	validation_0-mlogloss:1.05313
# [804]	validation_0-mlogloss:1.05313
# [805]	validation_0-mlogloss:1.05328
# [806]	validation_0-mlogloss:1.05321
# [807]	validation_0-mlogloss:1.05286
# [808]	validation_0-mlogloss:1.05289
# [809]	validation_0-mlogloss:1.05289
# [810]	validation_0-mlogloss:1.05256
# [811]	validation_0-mlogloss:1.05257
# [812]	validation_0-mlogloss:1.05252
# [813]	validation_0-mlogloss:1.05291
# [814]	validation_0-mlogloss:1.05277
# [815]	validation_0-mlogloss:1.05294
# [816]	validation_0-mlogloss:1.05304
# [817]	validation_0-mlogloss:1.05310
# [818]	validation_0-mlogloss:1.05350
# [819]	validation_0-mlogloss:1.05361
# [820]	validation_0-mlogloss:1.05355
# [821]	validation_0-mlogloss:1.05334
# [822]	validation_0-mlogloss:1.05332
# [823]	validation_0-mlogloss:1.05331
# [824]	validation_0-mlogloss:1.05312
# [825]	validation_0-mlogloss:1.05326
# [826]	validation_0-mlogloss:1.05331
# [827]	validation_0-mlogloss:1.05331
# [828]	validation_0-mlogloss:1.05329
# [829]	validation_0-mlogloss:1.05321
# [830]	validation_0-mlogloss:1.05298
# [831]	validation_0-mlogloss:1.05294
# [832]	validation_0-mlogloss:1.05294
# [833]	validation_0-mlogloss:1.05295
# [834]	validation_0-mlogloss:1.05298
# [835]	validation_0-mlogloss:1.05298
# [836]	validation_0-mlogloss:1.05297
# [837]	validation_0-mlogloss:1.05317
# [838]	validation_0-mlogloss:1.05316
# [839]	validation_0-mlogloss:1.05316
# [840]	validation_0-mlogloss:1.05316
# [841]	validation_0-mlogloss:1.05316
# [842]	validation_0-mlogloss:1.05316
# [843]	validation_0-mlogloss:1.05317
# [844]	validation_0-mlogloss:1.05317
# [845]	validation_0-mlogloss:1.05317
# [846]	validation_0-mlogloss:1.05316
# [847]	validation_0-mlogloss:1.05322
# [848]	validation_0-mlogloss:1.05321
# [849]	validation_0-mlogloss:1.05321
# [850]	validation_0-mlogloss:1.05320
# [851]	validation_0-mlogloss:1.05322
# [852]	validation_0-mlogloss:1.05324
# [853]	validation_0-mlogloss:1.05324
# [854]	validation_0-mlogloss:1.05324
# [855]	validation_0-mlogloss:1.05324
# [856]	validation_0-mlogloss:1.05324
# [857]	validation_0-mlogloss:1.05324
# [858]	validation_0-mlogloss:1.05318
# [859]	validation_0-mlogloss:1.05318
# [860]	validation_0-mlogloss:1.05317
# [861]	validation_0-mlogloss:1.05317
# [862]	validation_0-mlogloss:1.05317
# [863]	validation_0-mlogloss:1.05317
# [864]	validation_0-mlogloss:1.05317
# [865]	validation_0-mlogloss:1.05316
# [866]	validation_0-mlogloss:1.05271
# [867]	validation_0-mlogloss:1.05292
# [868]	validation_0-mlogloss:1.05339
# [869]	validation_0-mlogloss:1.05389
# [870]	validation_0-mlogloss:1.05468
# [871]	validation_0-mlogloss:1.05466
# [872]	validation_0-mlogloss:1.05467
# [873]	validation_0-mlogloss:1.05468
# [874]	validation_0-mlogloss:1.05469
# [875]	validation_0-mlogloss:1.05470
# [876]	validation_0-mlogloss:1.05470
# [877]	validation_0-mlogloss:1.05469
# [878]	validation_0-mlogloss:1.05470
# [879]	validation_0-mlogloss:1.05470
# [880]	validation_0-mlogloss:1.05470
# [881]	validation_0-mlogloss:1.05471
# [882]	validation_0-mlogloss:1.05471
# [883]	validation_0-mlogloss:1.05471
# [884]	validation_0-mlogloss:1.05472
# [885]	validation_0-mlogloss:1.05471
# [886]	validation_0-mlogloss:1.05472
# [887]	validation_0-mlogloss:1.05472
# [888]	validation_0-mlogloss:1.05472
# [889]	validation_0-mlogloss:1.05479
# [890]	validation_0-mlogloss:1.05479
# [891]	validation_0-mlogloss:1.05480
# [892]	validation_0-mlogloss:1.05480
# [893]	validation_0-mlogloss:1.05479
# [894]	validation_0-mlogloss:1.05479
# [895]	validation_0-mlogloss:1.05479
# [896]	validation_0-mlogloss:1.05479
# [897]	validation_0-mlogloss:1.05479
# [898]	validation_0-mlogloss:1.05480
# [899]	validation_0-mlogloss:1.05480
# [900]	validation_0-mlogloss:1.05480
# [901]	validation_0-mlogloss:1.05480
# [902]	validation_0-mlogloss:1.05480
# [903]	validation_0-mlogloss:1.05480
# [904]	validation_0-mlogloss:1.05480
# [905]	validation_0-mlogloss:1.05480
# [906]	validation_0-mlogloss:1.05480
# [907]	validation_0-mlogloss:1.05488
# [908]	validation_0-mlogloss:1.05488
# [909]	validation_0-mlogloss:1.05527
# [910]	validation_0-mlogloss:1.05527
# [911]	validation_0-mlogloss:1.05526
# [912]	validation_0-mlogloss:1.05526
# [913]	validation_0-mlogloss:1.05526
# [914]	validation_0-mlogloss:1.05526
# [915]	validation_0-mlogloss:1.05525
# [916]	validation_0-mlogloss:1.05525
# [917]	validation_0-mlogloss:1.05514
# [918]	validation_0-mlogloss:1.05515
# [919]	validation_0-mlogloss:1.05516
# [920]	validation_0-mlogloss:1.05517
# [921]	validation_0-mlogloss:1.05518
# [922]	validation_0-mlogloss:1.05518
# [923]	validation_0-mlogloss:1.05519
# [924]	validation_0-mlogloss:1.05522
# [925]	validation_0-mlogloss:1.05523
# [926]	validation_0-mlogloss:1.05524
# [927]	validation_0-mlogloss:1.05520
# [928]	validation_0-mlogloss:1.05516
# [929]	validation_0-mlogloss:1.05510
# [930]	validation_0-mlogloss:1.05503
# [931]	validation_0-mlogloss:1.05504
# [932]	validation_0-mlogloss:1.05504
# [933]	validation_0-mlogloss:1.05504
# [934]	validation_0-mlogloss:1.05505
# [935]	validation_0-mlogloss:1.05505
# [936]	validation_0-mlogloss:1.05506
# [937]	validation_0-mlogloss:1.05506
# [938]	validation_0-mlogloss:1.05506
# [939]	validation_0-mlogloss:1.05507
# [940]	validation_0-mlogloss:1.05507
# [941]	validation_0-mlogloss:1.05508
# [942]	validation_0-mlogloss:1.05507
# [943]	validation_0-mlogloss:1.05517
# [944]	validation_0-mlogloss:1.05517
# [945]	validation_0-mlogloss:1.05517
# [946]	validation_0-mlogloss:1.05517
# [947]	validation_0-mlogloss:1.05517
# [948]	validation_0-mlogloss:1.05517
# [949]	validation_0-mlogloss:1.05513
# [950]	validation_0-mlogloss:1.05513
# [951]	validation_0-mlogloss:1.05514
# [952]	validation_0-mlogloss:1.05514
# [953]	validation_0-mlogloss:1.05514
# [954]	validation_0-mlogloss:1.05514
# [955]	validation_0-mlogloss:1.05514
# [956]	validation_0-mlogloss:1.05520
# [957]	validation_0-mlogloss:1.05517
# [958]	validation_0-mlogloss:1.05517
# [959]	validation_0-mlogloss:1.05517
# [960]	validation_0-mlogloss:1.05517
# [961]	validation_0-mlogloss:1.05517
# [962]	validation_0-mlogloss:1.05518
# [963]	validation_0-mlogloss:1.05517
# [964]	validation_0-mlogloss:1.05517
# [965]	validation_0-mlogloss:1.05516
# [966]	validation_0-mlogloss:1.05516
# [967]	validation_0-mlogloss:1.05516
# [968]	validation_0-mlogloss:1.05502
# [969]	validation_0-mlogloss:1.05502
# [970]	validation_0-mlogloss:1.05502
# [971]	validation_0-mlogloss:1.05502
# [972]	validation_0-mlogloss:1.05501
# [973]	validation_0-mlogloss:1.05501
# [974]	validation_0-mlogloss:1.05502
# [975]	validation_0-mlogloss:1.05502
# [976]	validation_0-mlogloss:1.05502
# [977]	validation_0-mlogloss:1.05502
# [978]	validation_0-mlogloss:1.05502
# [979]	validation_0-mlogloss:1.05502
# [980]	validation_0-mlogloss:1.05502
# [981]	validation_0-mlogloss:1.05502
# [982]	validation_0-mlogloss:1.05502
# [983]	validation_0-mlogloss:1.05502
# [984]	validation_0-mlogloss:1.05502
# [985]	validation_0-mlogloss:1.05503
# [986]	validation_0-mlogloss:1.05503
# [987]	validation_0-mlogloss:1.05503
# [988]	validation_0-mlogloss:1.05503
# [989]	validation_0-mlogloss:1.05503
# [990]	validation_0-mlogloss:1.05502
# [991]	validation_0-mlogloss:1.05502
# [992]	validation_0-mlogloss:1.05503
# [993]	validation_0-mlogloss:1.05503
# [994]	validation_0-mlogloss:1.05503
# [995]	validation_0-mlogloss:1.05503
# [996]	validation_0-mlogloss:1.05503
# [997]	validation_0-mlogloss:1.05503
# [998]	validation_0-mlogloss:1.05502
# [999]	validation_0-mlogloss:1.05502
# [1000]	validation_0-mlogloss:1.05502
# [1001]	validation_0-mlogloss:1.05502
# [1002]	validation_0-mlogloss:1.05502
# [1003]	validation_0-mlogloss:1.05502
# [1004]	validation_0-mlogloss:1.05502
# [1005]	validation_0-mlogloss:1.05503
# [1006]	validation_0-mlogloss:1.05503
# [1007]	validation_0-mlogloss:1.05503
# [1008]	validation_0-mlogloss:1.05502
# [1009]	validation_0-mlogloss:1.05502
# [1010]	validation_0-mlogloss:1.05502
# [1011]	validation_0-mlogloss:1.05502
# [1012]	validation_0-mlogloss:1.05516
# [1013]	validation_0-mlogloss:1.05515
# [1014]	validation_0-mlogloss:1.05515
# [1015]	validation_0-mlogloss:1.05516
# [1016]	validation_0-mlogloss:1.05516
# [1017]	validation_0-mlogloss:1.05515
# [1018]	validation_0-mlogloss:1.05515
# [1019]	validation_0-mlogloss:1.05515
# [1020]	validation_0-mlogloss:1.05515
# [1021]	validation_0-mlogloss:1.05515
# [1022]	validation_0-mlogloss:1.05515
# [1023]	validation_0-mlogloss:1.05515
# [1024]	validation_0-mlogloss:1.05515
# [1025]	validation_0-mlogloss:1.05515
# [1026]	validation_0-mlogloss:1.05514
# [1027]	validation_0-mlogloss:1.05515
# [1028]	validation_0-mlogloss:1.05515
# [1029]	validation_0-mlogloss:1.05512
# [1030]	validation_0-mlogloss:1.05513
# [1031]	validation_0-mlogloss:1.05513
# [1032]	validation_0-mlogloss:1.05513
# [1033]	validation_0-mlogloss:1.05513
# [1034]	validation_0-mlogloss:1.05514
# [1035]	validation_0-mlogloss:1.05515
# [1036]	validation_0-mlogloss:1.05515
# [1037]	validation_0-mlogloss:1.05516
# [1038]	validation_0-mlogloss:1.05516
# [1039]	validation_0-mlogloss:1.05516
# [1040]	validation_0-mlogloss:1.05517
# [1041]	validation_0-mlogloss:1.05517
# [1042]	validation_0-mlogloss:1.05517
# [1043]	validation_0-mlogloss:1.05530
# [1044]	validation_0-mlogloss:1.05530
# [1045]	validation_0-mlogloss:1.05529
# [1046]	validation_0-mlogloss:1.05529
# [1047]	validation_0-mlogloss:1.05529
# [1048]	validation_0-mlogloss:1.05529
# [1049]	validation_0-mlogloss:1.05528
# [1050]	validation_0-mlogloss:1.05527
# [1051]	validation_0-mlogloss:1.05527
# [1052]	validation_0-mlogloss:1.05527
# [1053]	validation_0-mlogloss:1.05527
# [1054]	validation_0-mlogloss:1.05527
# [1055]	validation_0-mlogloss:1.05526
# [1056]	validation_0-mlogloss:1.05526
# [1057]	validation_0-mlogloss:1.05526
# [1058]	validation_0-mlogloss:1.05526
# [1059]	validation_0-mlogloss:1.05526
# [1060]	validation_0-mlogloss:1.05526
# [1061]	validation_0-mlogloss:1.05526
# [1062]	validation_0-mlogloss:1.05537
# [1063]	validation_0-mlogloss:1.05537
# [1064]	validation_0-mlogloss:1.05537
# [1065]	validation_0-mlogloss:1.05536
# [1066]	validation_0-mlogloss:1.05536
# [1067]	validation_0-mlogloss:1.05533
# [1068]	validation_0-mlogloss:1.05533
# [1069]	validation_0-mlogloss:1.05533
# [1070]	validation_0-mlogloss:1.05533
# [1071]	validation_0-mlogloss:1.05539
# [1072]	validation_0-mlogloss:1.05537
# [1073]	validation_0-mlogloss:1.05538
# [1074]	validation_0-mlogloss:1.05538
# [1075]	validation_0-mlogloss:1.05538
# [1076]	validation_0-mlogloss:1.05537
# [1077]	validation_0-mlogloss:1.05538
# [1078]	validation_0-mlogloss:1.05538
# [1079]	validation_0-mlogloss:1.05539
# [1080]	validation_0-mlogloss:1.05539
# [1081]	validation_0-mlogloss:1.05539
# [1082]	validation_0-mlogloss:1.05539
# [1083]	validation_0-mlogloss:1.05539
# [1084]	validation_0-mlogloss:1.05539
# [1085]	validation_0-mlogloss:1.05539
# [1086]	validation_0-mlogloss:1.05539
# [1087]	validation_0-mlogloss:1.05539
# [1088]	validation_0-mlogloss:1.05539
# [1089]	validation_0-mlogloss:1.05532
# [1090]	validation_0-mlogloss:1.05532
# [1091]	validation_0-mlogloss:1.05532
# [1092]	validation_0-mlogloss:1.05533
# [1093]	validation_0-mlogloss:1.05533
# [1094]	validation_0-mlogloss:1.05532
# [1095]	validation_0-mlogloss:1.05532
# [1096]	validation_0-mlogloss:1.05533
# [1097]	validation_0-mlogloss:1.05533
# [1098]	validation_0-mlogloss:1.05533
# [1099]	validation_0-mlogloss:1.05532
# [1100]	validation_0-mlogloss:1.05533
# [1101]	validation_0-mlogloss:1.05533
# [1102]	validation_0-mlogloss:1.05533
# [1103]	validation_0-mlogloss:1.05532
# [1104]	validation_0-mlogloss:1.05533
# [1105]	validation_0-mlogloss:1.05532
# [1106]	validation_0-mlogloss:1.05532
# [1107]	validation_0-mlogloss:1.05532
# [1108]	validation_0-mlogloss:1.05532
# [1109]	validation_0-mlogloss:1.05532
# [1110]	validation_0-mlogloss:1.05532
# [1111]	validation_0-mlogloss:1.05532
# [1112]	validation_0-mlogloss:1.05532
# [1113]	validation_0-mlogloss:1.05533
# [1114]	validation_0-mlogloss:1.05532
# [1115]	validation_0-mlogloss:1.05531
# [1116]	validation_0-mlogloss:1.05531
# [1117]	validation_0-mlogloss:1.05532
# [1118]	validation_0-mlogloss:1.05531
# [1119]	validation_0-mlogloss:1.05532
# [1120]	validation_0-mlogloss:1.05532
# [1121]	validation_0-mlogloss:1.05531
# [1122]	validation_0-mlogloss:1.05531
# [1123]	validation_0-mlogloss:1.05530
# [1124]	validation_0-mlogloss:1.05530
# [1125]	validation_0-mlogloss:1.05530
# [1126]	validation_0-mlogloss:1.05538
# [1127]	validation_0-mlogloss:1.05538
# [1128]	validation_0-mlogloss:1.05538
# [1129]	validation_0-mlogloss:1.05538
# [1130]	validation_0-mlogloss:1.05538
# [1131]	validation_0-mlogloss:1.05538
# [1132]	validation_0-mlogloss:1.05538
# [1133]	validation_0-mlogloss:1.05538
# [1134]	validation_0-mlogloss:1.05546
# [1135]	validation_0-mlogloss:1.05546
# [1136]	validation_0-mlogloss:1.05543
# [1137]	validation_0-mlogloss:1.05544
# [1138]	validation_0-mlogloss:1.05544
# [1139]	validation_0-mlogloss:1.05553
# [1140]	validation_0-mlogloss:1.05554
# [1141]	validation_0-mlogloss:1.05554
# [1142]	validation_0-mlogloss:1.05554
# [1143]	validation_0-mlogloss:1.05554
# [1144]	validation_0-mlogloss:1.05554
# [1145]	validation_0-mlogloss:1.05554
# [1146]	validation_0-mlogloss:1.05554
# [1147]	validation_0-mlogloss:1.05554
# [1148]	validation_0-mlogloss:1.05554
# [1149]	validation_0-mlogloss:1.05554
# [1150]	validation_0-mlogloss:1.05554
# [1151]	validation_0-mlogloss:1.05570
# [1152]	validation_0-mlogloss:1.05567
# [1153]	validation_0-mlogloss:1.05567
# [1154]	validation_0-mlogloss:1.05567
# [1155]	validation_0-mlogloss:1.05567
# [1156]	validation_0-mlogloss:1.05567
# [1157]	validation_0-mlogloss:1.05567
# [1158]	validation_0-mlogloss:1.05568
# [1159]	validation_0-mlogloss:1.05567
# [1160]	validation_0-mlogloss:1.05568
# [1161]	validation_0-mlogloss:1.05568
# [1162]	validation_0-mlogloss:1.05568
# [1163]	validation_0-mlogloss:1.05568
# [1164]	validation_0-mlogloss:1.05568
# [1165]	validation_0-mlogloss:1.05569
# [1166]	validation_0-mlogloss:1.05569
# [1167]	validation_0-mlogloss:1.05568
# [1168]	validation_0-mlogloss:1.05569
# [1169]	validation_0-mlogloss:1.05569
# [1170]	validation_0-mlogloss:1.05570
# [1171]	validation_0-mlogloss:1.05570
# [1172]	validation_0-mlogloss:1.05570
# [1173]	validation_0-mlogloss:1.05570
# [1174]	validation_0-mlogloss:1.05570
# [1175]	validation_0-mlogloss:1.05571
# [1176]	validation_0-mlogloss:1.05571
# [1177]	validation_0-mlogloss:1.05570
# [1178]	validation_0-mlogloss:1.05571
# [1179]	validation_0-mlogloss:1.05570
# [1180]	validation_0-mlogloss:1.05571
# [1181]	validation_0-mlogloss:1.05571
# [1182]	validation_0-mlogloss:1.05571
# [1183]	validation_0-mlogloss:1.05571
# [1184]	validation_0-mlogloss:1.05571
# [1185]	validation_0-mlogloss:1.05571
# [1186]	validation_0-mlogloss:1.05571
# [1187]	validation_0-mlogloss:1.05572
# [1188]	validation_0-mlogloss:1.05572
# [1189]	validation_0-mlogloss:1.05572
# [1190]	validation_0-mlogloss:1.05572
# [1191]	validation_0-mlogloss:1.05572
# [1192]	validation_0-mlogloss:1.05572
# [1193]	validation_0-mlogloss:1.05572
# [1194]	validation_0-mlogloss:1.05572
# [1195]	validation_0-mlogloss:1.05572
# [1196]	validation_0-mlogloss:1.05571
# [1197]	validation_0-mlogloss:1.05571
# [1198]	validation_0-mlogloss:1.05571
# [1199]	validation_0-mlogloss:1.05599
# [1200]	validation_0-mlogloss:1.05599
# [1201]	validation_0-mlogloss:1.05599
# [1202]	validation_0-mlogloss:1.05599
# [1203]	validation_0-mlogloss:1.05599
# [1204]	validation_0-mlogloss:1.05595
# [1205]	validation_0-mlogloss:1.05564
# [1206]	validation_0-mlogloss:1.05559
# [1207]	validation_0-mlogloss:1.05561
# [1208]	validation_0-mlogloss:1.05561
# [1209]	validation_0-mlogloss:1.05562
# [1210]	validation_0-mlogloss:1.05563
# [1211]	validation_0-mlogloss:1.05564
# [1212]	validation_0-mlogloss:1.05565
# [1213]	validation_0-mlogloss:1.05566
# [1214]	validation_0-mlogloss:1.05591
# [1215]	validation_0-mlogloss:1.05592
# [1216]	validation_0-mlogloss:1.05593
# [1217]	validation_0-mlogloss:1.05594
# [1218]	validation_0-mlogloss:1.05595
# [1219]	validation_0-mlogloss:1.05596
# [1220]	validation_0-mlogloss:1.05596
# [1221]	validation_0-mlogloss:1.05597
# [1222]	validation_0-mlogloss:1.05597
# [1223]	validation_0-mlogloss:1.05598
# [1224]	validation_0-mlogloss:1.05598
# [1225]	validation_0-mlogloss:1.05598
# [1226]	validation_0-mlogloss:1.05599
# [1227]	validation_0-mlogloss:1.05600
# [1228]	validation_0-mlogloss:1.05601
# [1229]	validation_0-mlogloss:1.05601
# [1230]	validation_0-mlogloss:1.05621
# [1231]	validation_0-mlogloss:1.05622
# [1232]	validation_0-mlogloss:1.05622
# [1233]	validation_0-mlogloss:1.05623
# [1234]	validation_0-mlogloss:1.05624
# [1235]	validation_0-mlogloss:1.05625
# [1236]	validation_0-mlogloss:1.05625
# [1237]	validation_0-mlogloss:1.05626
# [1238]	validation_0-mlogloss:1.05626
# [1239]	validation_0-mlogloss:1.05627
# [1240]	validation_0-mlogloss:1.05627
# [1241]	validation_0-mlogloss:1.05627
# [1242]	validation_0-mlogloss:1.05628
# [1243]	validation_0-mlogloss:1.05628
# [1244]	validation_0-mlogloss:1.05622
# [1245]	validation_0-mlogloss:1.05628
# [1246]	validation_0-mlogloss:1.05628
# [1247]	validation_0-mlogloss:1.05628
# [1248]	validation_0-mlogloss:1.05629
# [1249]	validation_0-mlogloss:1.05630
# [1250]	validation_0-mlogloss:1.05630
# [1251]	validation_0-mlogloss:1.05633
# [1252]	validation_0-mlogloss:1.05633
# [1253]	validation_0-mlogloss:1.05634
# [1254]	validation_0-mlogloss:1.05639
# [1255]	validation_0-mlogloss:1.05639
# [1256]	validation_0-mlogloss:1.05640
# [1257]	validation_0-mlogloss:1.05640
# [1258]	validation_0-mlogloss:1.05641
# [1259]	validation_0-mlogloss:1.05641
# [1260]	validation_0-mlogloss:1.05641
# [1261]	validation_0-mlogloss:1.05641
# [1262]	validation_0-mlogloss:1.05642
# [1263]	validation_0-mlogloss:1.05643
# [1264]	validation_0-mlogloss:1.05641
# [1265]	validation_0-mlogloss:1.05641
# [1266]	validation_0-mlogloss:1.05642
# [1267]	validation_0-mlogloss:1.05642
# [1268]	validation_0-mlogloss:1.05642
# [1269]	validation_0-mlogloss:1.05642
# [1270]	validation_0-mlogloss:1.05643
# [1271]	validation_0-mlogloss:1.05642
# [1272]	validation_0-mlogloss:1.05642
# [1273]	validation_0-mlogloss:1.05643
# [1274]	validation_0-mlogloss:1.05643
# [1275]	validation_0-mlogloss:1.05644
# [1276]	validation_0-mlogloss:1.05644
# [1277]	validation_0-mlogloss:1.05644
# [1278]	validation_0-mlogloss:1.05644
# [1279]	validation_0-mlogloss:1.05644
# [1280]	validation_0-mlogloss:1.05644
# [1281]	validation_0-mlogloss:1.05645
# [1282]	validation_0-mlogloss:1.05645
# [1283]	validation_0-mlogloss:1.05644
# [1284]	validation_0-mlogloss:1.05645
# [1285]	validation_0-mlogloss:1.05645
# [1286]	validation_0-mlogloss:1.05645
# [1287]	validation_0-mlogloss:1.05645
# [1288]	validation_0-mlogloss:1.05645
# [1289]	validation_0-mlogloss:1.05645
# [1290]	validation_0-mlogloss:1.05646
# [1291]	validation_0-mlogloss:1.05646
# [1292]	validation_0-mlogloss:1.05646
# [1293]	validation_0-mlogloss:1.05646
# [1294]	validation_0-mlogloss:1.05650
# [1295]	validation_0-mlogloss:1.05650
# [1296]	validation_0-mlogloss:1.05650
# [1297]	validation_0-mlogloss:1.05665
# [1298]	validation_0-mlogloss:1.05665
# [1299]	validation_0-mlogloss:1.05665
# [1300]	validation_0-mlogloss:1.05665
# [1301]	validation_0-mlogloss:1.05665
# [1302]	validation_0-mlogloss:1.05665
# [1303]	validation_0-mlogloss:1.05665
# [1304]	validation_0-mlogloss:1.05665
# [1305]	validation_0-mlogloss:1.05666
# [1306]	validation_0-mlogloss:1.05666
# [1307]	validation_0-mlogloss:1.05666
# [1308]	validation_0-mlogloss:1.05666
# [1309]	validation_0-mlogloss:1.05666
# [1310]	validation_0-mlogloss:1.05666
# [1311]	validation_0-mlogloss:1.05666
# [1312]	validation_0-mlogloss:1.05666
# [1313]	validation_0-mlogloss:1.05667
# [1314]	validation_0-mlogloss:1.05666
# [1315]	validation_0-mlogloss:1.05666
# [1316]	validation_0-mlogloss:1.05667
# [1317]	validation_0-mlogloss:1.05666
# [1318]	validation_0-mlogloss:1.05666
# [1319]	validation_0-mlogloss:1.05673
# [1320]	validation_0-mlogloss:1.05671
# [1321]	validation_0-mlogloss:1.05670
# [1322]	validation_0-mlogloss:1.05670
# [1323]	validation_0-mlogloss:1.05670
# [1324]	validation_0-mlogloss:1.05670
# [1325]	validation_0-mlogloss:1.05670
# [1326]	validation_0-mlogloss:1.05670
# [1327]	validation_0-mlogloss:1.05670
# [1328]	validation_0-mlogloss:1.05670
# [1329]	validation_0-mlogloss:1.05670
# [1330]	validation_0-mlogloss:1.05669
# [1331]	validation_0-mlogloss:1.05669
# [1332]	validation_0-mlogloss:1.05669
# [Fold 0] f1_macro = 0.767
